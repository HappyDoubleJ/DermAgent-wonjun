# %%
import pandas as pd

df = pd.read_csv('Derm1M_v2_pretrain.csv')

# 두 열만 선택
labels_df = df[['disease_label', 'hierarchical_disease_label']]

# 표시 옵션 설정 (긴 텍스트도 잘리지 않게)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 50)

# 확인
print(f"전체 행 수: {len(labels_df)}")
labels_df.head(30)
# Out:
# 전체 행 수: 413210
#                                                              disease_label  \
# 0                                                    epidermolysis bullosa
# 1                                                  no definitive diagnosis
# 2   erythrasma, pitriasis versicolor, tenia capitis, trichophyton shonleni
# 3                                                                    ulcer
# 4                                                                    nevus
# 5                                                            herpes zoster
# 6                                                  neonatal toxic erythema
# 7                                                           ashidermatosis
# 8                                                                syringoma
# 9                                                     basal cell carcinoma
# 10                          irritated seborrheic keratosis (from "sk/isk")
# 11                                                eczema, pityriasis rosea
# 12                                                     sclerema neonatorum
# 13                                                 no definitive diagnosis
# 14                                                 no definitive diagnosis
# 15                                                 no definitive diagnosis
# 16                                                               psoriasis
# 17                                                 no definitive diagnosis
# 18                                                    basal cell carcinoma
# 19                                                           herpes zoster
# 20                                                 no definitive diagnosis
# 21                                         mycobacterium marinum infection
# 22                                                           acne, rosacea
# 23                                   eczema, stasis dermatitis, dermatitis
# 24                                                               psoriasis
# 25                                                      clinical diagnosis
# 26                                                 no definitive diagnosis
# 27                                                                alopecia
# 28                                                              hemangioma
# 29                                                 no definitive diagnosis
#
#                                                                                        hierarchical_disease_label
# 0                                                                               hereditary, epidermolysis bullosa
# 1                                                                                         no definitive diagnosis
# 2                                          erythrasma, pitriasis versicolor, tenia capitis, trichophyton shonleni
# 3                                         reaction patterns and descriptive terms, ulcers, erosion of skin, ulcer
# 4                                                                                                           nevus
# 5                                                                  inflammatory, infectious, viral, herpes zoster
# 6                                                                                         neonatal toxic erythema
# 7                                                                                                  ashidermatosis
# 8                                                              proliferations, benign, non-melanocytic, syringoma
# 9                                                proliferations, malignant, non-melanocytic, basal cell carcinoma
# 10  proliferations, benign, non-melanocytic, seborrheic keratosis, irritated seborrheic keratosis (from "sk/isk")
# 11                                                         inflammatory, non-infectious, eczema, pityriasis rosea
# 12                                                                                            sclerema neonatorum
# 13                                                                                                            NaN
# 14                                                                                                            NaN
# 15                                                                                                            NaN
# 16                                                                        inflammatory, non-infectious, psoriasis
# 17                                                                                                            NaN
# 18                                               proliferations, malignant, non-melanocytic, basal cell carcinoma
# 19                                                                 inflammatory, infectious, viral, herpes zoster
# 20                                                                                                            NaN
# 21                                                                                mycobacterium marinum infection
# 22                                                                    inflammatory, non-infectious, acne, rosacea
# 23                                            inflammatory, non-infectious, eczema, stasis dermatitis, dermatitis
# 24                                                                        inflammatory, non-infectious, psoriasis
# 25                                                                                             clinical diagnosis
# 26                                                                                                            NaN
# 27                                                                                        hair diseases, alopecia
# 28                                                   proliferations, benign, non-melanocytic, angioma, hemangioma
# 29                                                                                                            NaN

# %%
import pandas as pd
import json

# ontology.json 읽기
with open('ontology.json', 'r') as f:
    ontology = json.load(f)

# 리프 노드 (자식이 없는 노드)
leaf_nodes = set([node for node, children in ontology.items() if children == [] and node != 'root'])

# 중간 노드 (자식이 있는 노드)
internal_nodes = set([node for node, children in ontology.items() if children != [] and node != 'root'])

# 모든 유효 노드 (리프 + 중간)
valid_nodes = leaf_nodes | internal_nodes
valid_nodes_lower = set([node.lower() for node in valid_nodes])

print(f"리프 노드 개수: {len(leaf_nodes)}")
print(f"중간 노드 개수: {len(internal_nodes)}")
print(f"전체 유효 노드 개수: {len(valid_nodes)}")

# CSV 파일 읽기
df = pd.read_csv('Derm1M_v2_pretrain.csv')

print(f"\n전체 데이터: {len(df)}개")

# 모든 disease_label에 대해 확인 (단일값 + 복수값 모두)
def check_in_ontology(disease_label):
    if pd.isna(disease_label):
        return False, [], []
    
    # 콤마로 분리 (단일값도 리스트로 변환됨)
    diseases = [d.strip() for d in str(disease_label).split(',')]
    
    # 각 질환이 온톨로지에 있는지 확인
    in_valid = [d.lower() in valid_nodes_lower for d in diseases]
    
    return all(in_valid), diseases, in_valid

# 전체 데이터에 적용
df['all_in_ontology'], df['diseases_list'], df['in_valid_list'] = zip(*df['disease_label'].apply(check_in_ontology))

# 통계
total = len(df)
in_ontology_count = df['all_in_ontology'].sum()

print(f"\n온톨로지에 있음: {in_ontology_count}개 ({in_ontology_count/total*100:.1f}%)")
print(f"온톨로지에 없음: {total - in_ontology_count}개 ({(total - in_ontology_count)/total*100:.1f}%)")

# 온톨로지에 있는 데이터만 필터링
df_in_ontology = df[df['all_in_ontology']].copy()

# 단일 vs 복수 질환
single = df_in_ontology[~df_in_ontology['disease_label'].str.contains(',', na=False)]
multi = df_in_ontology[df_in_ontology['disease_label'].str.contains(',', na=False)]

print(f"\n온톨로지에 있는 데이터:")
print(f"  - 단일 질환: {len(single)}개")
print(f"  - 복수 질환: {len(multi)}개")

# 결과 확인 (처음 50개)
result_df = df[['disease_label', 'diseases_list', 'in_valid_list', 'all_in_ontology']].head(50)
pd.set_option('display.max_colwidth', None)
result_df
# Out:
# 리프 노드 개수: 317
# 중간 노드 개수: 52
# 전체 유효 노드 개수: 369
#
# 전체 데이터: 413210개
#
# 온톨로지에 있음: 176586개 (42.7%)
# 온톨로지에 없음: 236624개 (57.3%)
#
# 온톨로지에 있는 데이터:
#   - 단일 질환: 162027개
#   - 복수 질환: 14559개
#                                                              disease_label  \
# 0                                                    epidermolysis bullosa
# 1                                                  no definitive diagnosis
# 2   erythrasma, pitriasis versicolor, tenia capitis, trichophyton shonleni
# 3                                                                    ulcer
# 4                                                                    nevus
# 5                                                            herpes zoster
# 6                                                  neonatal toxic erythema
# 7                                                           ashidermatosis
# 8                                                                syringoma
# 9                                                     basal cell carcinoma
# 10                          irritated seborrheic keratosis (from "sk/isk")
# 11                                                eczema, pityriasis rosea
# 12                                                     sclerema neonatorum
# 13                                                 no definitive diagnosis
# 14                                                 no definitive diagnosis
# 15                                                 no definitive diagnosis
# 16                                                               psoriasis
# 17                                                 no definitive diagnosis
# 18                                                    basal cell carcinoma
# 19                                                           herpes zoster
# 20                                                 no definitive diagnosis
# 21                                         mycobacterium marinum infection
# 22                                                           acne, rosacea
# 23                                   eczema, stasis dermatitis, dermatitis
# 24                                                               psoriasis
# 25                                                      clinical diagnosis
# 26                                                 no definitive diagnosis
# 27                                                                alopecia
# 28                                                              hemangioma
# 29                                                 no definitive diagnosis
# 30                                                                melanoma
# 31                                                 no definitive diagnosis
# 32                                                      acne, folliculitis
# 33                                                               psoriasis
# 34                                                  epidermal nevus, nevus
# 35                                  cutaneous blood disorder manifestation
# 36                                                 no definitive diagnosis
# 37                                                            nail disease
# 38                                             allergic contact dermatitis
# 39                                                 no definitive diagnosis
# 40                                                                syphilis
# 41                                                 no definitive diagnosis
# 42                                        cutaneous albinism manifestation
# 43                                                                syphilis
# 44                                                                syphilis
# 45                                                          proliferations
# 46                                                                  eczema
# 47                                                                    cyst
# 48                                                 no definitive diagnosis
# 49                                                 no definitive diagnosis
#
#                                                                diseases_list  \
# 0                                                    [epidermolysis bullosa]
# 1                                                  [no definitive diagnosis]
# 2   [erythrasma, pitriasis versicolor, tenia capitis, trichophyton shonleni]
# 3                                                                    [ulcer]
# 4                                                                    [nevus]
# 5                                                            [herpes zoster]
# 6                                                  [neonatal toxic erythema]
# 7                                                           [ashidermatosis]
# 8                                                                [syringoma]
# 9                                                     [basal cell carcinoma]
# 10                          [irritated seborrheic keratosis (from "sk/isk")]
# 11                                                [eczema, pityriasis rosea]
# 12                                                     [sclerema neonatorum]
# 13                                                 [no definitive diagnosis]
# 14                                                 [no definitive diagnosis]
# 15                                                 [no definitive diagnosis]
# 16                                                               [psoriasis]
# 17                                                 [no definitive diagnosis]
# 18                                                    [basal cell carcinoma]
# 19                                                           [herpes zoster]
# 20                                                 [no definitive diagnosis]
# 21                                         [mycobacterium marinum infection]
# 22                                                           [acne, rosacea]
# 23                                   [eczema, stasis dermatitis, dermatitis]
# 24                                                               [psoriasis]
# 25                                                      [clinical diagnosis]
# 26                                                 [no definitive diagnosis]
# 27                                                                [alopecia]
# 28                                                              [hemangioma]
# 29                                                 [no definitive diagnosis]
# 30                                                                [melanoma]
# 31                                                 [no definitive diagnosis]
# 32                                                      [acne, folliculitis]
# 33                                                               [psoriasis]
# 34                                                  [epidermal nevus, nevus]
# 35                                  [cutaneous blood disorder manifestation]
# 36                                                 [no definitive diagnosis]
# 37                                                            [nail disease]
# 38                                             [allergic contact dermatitis]
# 39                                                 [no definitive diagnosis]
# 40                                                                [syphilis]
# 41                                                 [no definitive diagnosis]
# 42                                        [cutaneous albinism manifestation]
# 43                                                                [syphilis]
# 44                                                                [syphilis]
# 45                                                          [proliferations]
# 46                                                                  [eczema]
# 47                                                                    [cyst]
# 48                                                 [no definitive diagnosis]
# 49                                                 [no definitive diagnosis]
#
#                    in_valid_list  all_in_ontology
# 0                         [True]             True
# 1                        [False]            False
# 2   [False, False, False, False]            False
# 3                         [True]             True
# 4                        [False]            False
# 5                         [True]             True
# 6                        [False]            False
# 7                        [False]            False
# 8                         [True]             True
# 9                         [True]             True
# 10                        [True]             True
# 11                  [True, True]             True
# 12                       [False]            False
# 13                       [False]            False
# 14                       [False]            False
# 15                       [False]            False
# 16                        [True]             True
# 17                       [False]            False
# 18                        [True]             True
# 19                        [True]             True
# 20                       [False]            False
# 21                       [False]            False
# 22                 [False, True]            False
# 23           [True, True, False]            False
# 24                        [True]             True
# 25                       [False]            False
# 26                       [False]            False
# 27                       [False]            False
# 28                       [False]            False
# 29                       [False]            False
# 30                       [False]            False
# 31                       [False]            False
# 32                 [False, True]            False
# 33                        [True]             True
# 34                 [True, False]            False
# 35                       [False]            False
# 36                       [False]            False
# 37                       [False]            False
# 38                        [True]             True
# 39                       [False]            False
# 40                        [True]             True
# 41                       [False]            False
# 42                       [False]            False
# 43                        [True]             True
# 44                        [True]             True
# 45                        [True]             True
# 46                        [True]             True
# 47                       [False]            False
# 48                       [False]            False
# 49                       [False]            False

# %%
import pandas as pd
import json

# ontology.json 읽기
with open('ontology.json', 'r') as f:
    ontology = json.load(f)

# 리프 노드 + 중간 노드 (총 369개)
leaf_nodes = set([node for node, children in ontology.items() if children == [] and node != 'root'])
internal_nodes = set([node for node, children in ontology.items() if children != [] and node != 'root'])
valid_nodes = leaf_nodes | internal_nodes
valid_nodes_lower = set([node.lower() for node in valid_nodes])

print(f"전체 유효 노드 개수: {len(valid_nodes)}")

# CSV 파일 읽기
df = pd.read_csv('Derm1M_v2_pretrain.csv')

# 각 disease_label을 콤마로 분리 (단일값도 포함)
def check_in_ontology(disease_label):
    if pd.isna(disease_label):
        return False, []
    
    diseases = [d.strip() for d in str(disease_label).split(',')]
    in_valid = [d.lower() in valid_nodes_lower for d in diseases]
    return all(in_valid), diseases

df['in_ontology'], df['diseases_list'] = zip(*df['disease_label'].apply(check_in_ontology))

# 통계
total = len(df)
in_ontology_count = df['in_ontology'].sum()

print(f"\n전체 데이터: {total}개")
print(f"온톨로지에 있음: {in_ontology_count}개 ({in_ontology_count/total*100:.1f}%)")
print(f"온톨로지에 없음: {total - in_ontology_count}개 ({(total - in_ontology_count)/total*100:.1f}%)")

# 온톨로지에 있는 데이터만 필터링
df_filtered = df[df['in_ontology']].copy()
print(f"\n필터링된 데이터: {len(df_filtered)}개")
# Out:
# 전체 유효 노드 개수: 369
#
# 전체 데이터: 413210개
# 온톨로지에 있음: 176586개 (42.7%)
# 온톨로지에 없음: 236624개 (57.3%)
#
# 필터링된 데이터: 176586개

# %%
import json
from collections import deque

with open('ontology.json', 'r') as f:
    ontology = json.load(f)

def count_nodes_by_depth_unique(ontology):
    """중복 없이 각 노드의 깊이 계산 (가장 짧은 경로 기준)"""
    depth_map = {}  # 노드별 깊이 저장
    visited = set()
    queue = deque([('root', 0)])
    
    while queue:
        node, depth = queue.popleft()
        
        # 이미 방문한 노드는 건너뛰기 (더 짧은 경로를 이미 찾음)
        if node in visited:
            continue
        
        visited.add(node)
        if node != 'root':  # root는 제외
            depth_map[node] = depth
        
        if node in ontology:
            for child in ontology[node]:
                if child not in visited:
                    queue.append((child, depth + 1))
    
    return depth_map

depth_map = count_nodes_by_depth_unique(ontology)

# 깊이별 노드 수 계산
depth_counts = {}
for node, depth in depth_map.items():
    depth_counts[depth] = depth_counts.get(depth, 0) + 1

print(f"총 노드 수 (root 제외): {len(depth_map)}")
print("\n각 레벨별 노드 수:")
for depth in sorted(depth_counts.keys()):
    print(f"Level {depth}: {depth_counts[depth]}개")

print(f"\n전체 합계: {sum(depth_counts.values())}개")

# 리프 노드 확인
leaf_nodes = [node for node, children in ontology.items() if children == [] and node != 'root']
print(f"\n리프 노드 수: {len(leaf_nodes)}")
# Out:
# 총 노드 수 (root 제외): 369
#
# 각 레벨별 노드 수:
# Level 1: 7개
# Level 2: 88개
# Level 3: 107개
# Level 4: 148개
# Level 5: 19개
#
# 전체 합계: 369개
#
# 리프 노드 수: 317

# %%
import pandas as pd
import json

# ontology.json 읽기
with open('ontology.json', 'r') as f:
    ontology = json.load(f)

# 리프 노드 + 중간 노드
leaf_nodes = set([node for node, children in ontology.items() if children == [] and node != 'root'])
internal_nodes = set([node for node, children in ontology.items() if children != [] and node != 'root'])
valid_nodes = leaf_nodes | internal_nodes
valid_nodes.add('no definitive diagnosis')
valid_nodes_lower = set([node.lower() for node in valid_nodes])

print(f"온톨로지 노드 수: {len(valid_nodes)}개")

# CSV 파일 읽기
df = pd.read_csv('Derm1M_v2_pretrain.csv')
print(f"전체 데이터 수: {len(df):,}개")

# 온톨로지 필터링
def check_in_ontology(disease_label):
    if pd.isna(disease_label):
        return False
    diseases = [d.strip() for d in str(disease_label).split(',')]
    in_valid = [d.lower() in valid_nodes_lower for d in diseases]
    return all(in_valid)

df['in_ontology'] = df['disease_label'].apply(check_in_ontology)
df_filtered = df[df['in_ontology']].copy()

print(f"온톨로지에 있는 데이터: {len(df_filtered):,}개 ({len(df_filtered)/len(df)*100:.1f}%)\n")

# 질환별 분포 (높은 순서대로)
disease_counts = df_filtered['disease_label'].value_counts()

print(f"총 질환 종류 수: {len(disease_counts)}개\n")
print("="*80)
print(f"{'순위':<5} {'질환명':<60} {'샘플 수':<10} {'비율'}")
print("="*80)

for i, (disease, count) in enumerate(disease_counts.items(), 1):
    percentage = count / len(df_filtered) * 100
    print(f"{i:<5} {disease:<60} {count:<10} {percentage:>6.2f}%")
    
    if i == 50:  # 상위 50개만 출력
        print("\n... (나머지 생략) ...")
        break

print("="*80)
# Out:
# 온톨로지 노드 수: 370개
# 전체 데이터 수: 413,210개
# 온톨로지에 있는 데이터: 279,150개 (67.6%)
#
# 총 질환 종류 수: 1212개
#
# ================================================================================
# 순위    질환명                                                          샘플 수       비율
# ================================================================================
# 1     no definitive diagnosis                                      102380      36.68%
# 2     allergic contact dermatitis                                  47510       17.02%
# 3     irritated seborrheic keratosis (from "sk/isk")               15906        5.70%
# 4     psoriasis                                                    13794        4.94%
# 5     eczema                                                       6808         2.44%
# 6     basal cell carcinoma                                         4683         1.68%
# 7     proliferations                                               3448         1.24%
# 8     squamous cell carcinoma                                      3132         1.12%
# 9     urticaria                                                    2859         1.02%
# 10    lichen planus                                                2317         0.83%
# 11    molluscum contagiosum                                        2029         0.73%
# 12    vitiligo                                                     2022         0.72%
# 13    seborrheic keratoses                                         1823         0.65%
# 14    lichen planus, psoriasis                                     1723         0.62%
# 15    herpes zoster                                                1694         0.61%
# 16    ulcer                                                        1655         0.59%
# 17    contact dermatitis                                           1639         0.59%
# 18    candidiasis, tinea                                           1617         0.58%
# 19    tinea                                                        1453         0.52%
# 20    scabies                                                      1450         0.52%
# 21    herpes simplex virus                                         1393         0.50%
# 22    folliculitis                                                 1303         0.47%
# 23    impetigo                                                     1273         0.46%
# 24    skin diseases caused by warts                                1188         0.43%
# 25    lupus erythematosus                                          1183         0.42%
# 26    rosacea                                                      1169         0.42%
# 27    scar                                                         1039         0.37%
# 28    kaposi sarcoma                                               1028         0.37%
# 29    cellulitis                                                   1003         0.36%
# 30    bullous pemphigoid                                           976          0.35%
# 31    ichthyosis                                                   954          0.34%
# 32    pityriasis rosea                                             948          0.34%
# 33    erythema multiforme                                          929          0.33%
# 34    epidermolysis bullosa                                        905          0.32%
# 35    syphilis                                                     893          0.32%
# 36    onychomycosis                                                863          0.31%
# 37    dermatofibroma                                               863          0.31%
# 38    stevens-johnson syndrome                                     830          0.30%
# 39    mycosis fungoides                                            800          0.29%
# 40    bullous disease                                              772          0.28%
# 41    acanthosis nigricans                                         730          0.26%
# 42    hyperpigmentation                                            699          0.25%
# 43    varicella                                                    688          0.25%
# 44    candidiasis                                                  664          0.24%
# 45    pemphigus vulgaris                                           623          0.22%
# 46    abscess                                                      623          0.22%
# 47    pyogenic granuloma                                           603          0.22%
# 48    cutaneous lupus, lupus erythematosus                         598          0.21%
# 49    foot ulcer, ulcer                                            591          0.21%
# 50    tinea, tinea corporis                                        573          0.21%
#
# ... (나머지 생략) ...
# ================================================================================
